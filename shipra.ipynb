# %%
from scipy import stats
import seaborn as sns
import pandas as pd
import numpy

# %%
df = pd.read_csv('data.csv')

# %%
df.columns
# Out:
# Index(['Delivery_Time', 'Customer_Rating', 'Product_Cost', 'Discount_Offered',
#        'Weight_in_gms'],
#       dtype='object')

# %%
from fitter import Fitter,get_common_distributions, get_distributions

# %%
f = Fitter(df['Delivery_Time'], distributions=get_common_distributions())
f.fit(max_workers=1)
f.summary()
# Out:
# 2025-10-21 14:02:00.549 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted cauchy distribution with error=0.179371)
# 2025-10-21 14:02:00.602 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted chi2 distribution with error=0.013972)
# 2025-10-21 14:02:00.607 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted expon distribution with error=0.014865)
# 2025-10-21 14:02:00.714 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted exponpow distribution with error=0.072672)
# 2025-10-21 14:02:00.760 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted gamma distribution with error=0.013509)
# 2025-10-21 14:02:00.766 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted lognorm distribution with error=0.039694)
# 2025-10-21 14:02:00.771 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted norm distribution with error=0.251392)
# 2025-10-21 14:02:00.781 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted powerlaw distribution with error=0.173098)
# 2025-10-21 14:02:00.787 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted rayleigh distribution with error=0.197662)
# 2025-10-21 14:02:00.793 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted uniform distribution with error=0.56121)
#           sumsquare_error          aic          bic  kl_div  ks_statistic  \
# gamma            0.013509  1051.739691  1066.462957     inf      0.019120
# chi2             0.013972  1019.263287  1033.986553     inf      0.017092
# expon            0.014865  1061.090121  1070.905632     inf      0.028268
# lognorm          0.039694   958.618199   973.341465     inf      0.053492
# exponpow         0.072672   935.134873   949.858139     inf      0.174524
#
#              ks_pvalue
# gamma     8.510688e-01
# chi2      9.271279e-01
# expon     3.939171e-01
# lognorm   6.296452e-03
# exponpow  4.148171e-27

# %%
f = Fitter(df['Customer_Rating'], distributions=get_common_distributions())
f.fit(max_workers=1)
f.summary()
# Out:
# 2025-10-21 14:04:23.617 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted cauchy distribution with error=2.161798)
# 2025-10-21 14:04:29.210 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted chi2 distribution with error=1.542618)
# 2025-10-21 14:04:29.361 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted expon distribution with error=2.192061)
# 2025-10-21 14:04:33.588 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted exponpow distribution with error=1.208358)
# 2025-10-21 14:04:38.710 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted gamma distribution with error=1.506344)
# 2025-10-21 14:04:39.258 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted lognorm distribution with error=1.502499)
# 2025-10-21 14:04:39.399 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted norm distribution with error=1.502485)
# 2025-10-21 14:04:40.008 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted powerlaw distribution with error=0.596094)
# 2025-10-21 14:04:40.161 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted rayleigh distribution with error=1.486314)
# 2025-10-21 14:04:40.270 | INFO     | fitter.fitter:_fit_single_distribution:333 - Fitted uniform distribution with error=0.591996)
#           sumsquare_error         aic         bic    kl_div  ks_statistic  \
# uniform          0.591996  280.496514  290.312024  0.050651      0.029382
# powerlaw         0.596094  282.618374  297.341640  0.050830      0.039191
# exponpow         1.208358  302.098732  316.821997  0.101502      0.075506
# rayleigh         1.486314  311.007118  320.822629  0.127282      0.088982
# norm             1.502485  315.869001  325.684511  0.131498      0.069877
#
#              ks_pvalue
# uniform   3.470458e-01
# powerlaw  9.023180e-02
# exponpow  2.098680e-05
# rayleigh  2.439053e-07
# norm      1.086382e-04
